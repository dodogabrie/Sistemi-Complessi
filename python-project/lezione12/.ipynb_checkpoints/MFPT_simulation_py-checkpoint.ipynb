# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from scipy.stats import kde

# %%
def get_param():
    n = 2000 # step di ogni camminatore
    m = 100000 # camminatori analizzati
    dt = 0.008
    eps = 0.0005
    return n, m, dt, eps

# %%
def f(x):
    '''Forza applicata sui camminatori'''
    return x-x**3

def step(x, dw, dt, eps):
    '''Incremento sulla posizione'''
    return f(x)*dt + np.sqrt(eps)*dw

def motion(x, dw):
    '''Gestione del movimento del camminatore'''
    n, m, dt, eps = get_param()
    print('start cycling')
    for i in range(n-1):
        x[i+1,:] = x[i,:] + step(x[i,:], dw[i,:], dt, eps)  # Notazione vettoriale
        # Visualizzo la velocità del loop (dura circa 4s in tutto)
        if i == int((n-1)/4):
            print('25%')
        if i == int((n-1)/2):
            print('50%')
        if i == int(3*(n-1)/4):
            print('75%')
        if i == n-2:
            print('done')
    return x

# %%
def main():
    np.random.seed(10) # Risultati riproducibili
    mu, sigma = 0, 1 # media e deviazione standard del processo di Wiener
    n, m, dt, eps = get_param() # prendo i parametri del problema
    
    # Inizializzo matrice delle posizioni e dei numeri casuali
    print('setting up')
    print('-ones matrix...')
    x = -1*np.ones((n,m)) # Tutti in -1 all'inizio
    print('rand matrix, wait some seconds...')
    dw = np.random.normal(mu, sigma, (n,m))
    
    # muovo i camminatori
    x = motion(x, dw)
    
    # Plotto i risultati e memorizzo i giusti percorsi e le giuste w
    right_paths = []
    right_w = []
    
    tj = n*dt
    t = np.arange(0,n*dt,dt)
    plt.figure(figsize=(20,10))
    for i in range(m):
        j = np.argmax(x[:,i]>=1) # Cerco la prima volta che è stato superato x=1
        if j > 0: # se fa 0 allora vuol dire che non ci è arrivato...
            plt.plot(t - t[j], x[:,i], alpha=0.7)
            right_paths.append(x[:,i])
            right_w.append(dw[:,i])
            if tj > t[j]:
                tj = t[j]
    plt.xlim(-3*tj,0)
    plt.show()
    return right_paths, right_w
p, w = main()
# Out:
# setting up
# -ones matrix...
# rand matrix, wait some seconds...
# start cycling
# 25%
# 50%
# 75%
# done

# %%
print(f'Numero di percorsi ottenuti: {len(p)}')
n, m, dt, eps = get_param()
print(f'rapporto eps/dt = {eps/dt}')
#%reset
# Out:
# Numero di percorsi ottenuti: 71
# rapporto eps/dt = 0.0625

# %%
'''Per poter lavorare con i path ottenuti serve che:
    - Abbiano tutti lo zero dei tempi quando hanno toccato x = 1
    - 
'''

n, m, dt, eps = get_param()
t = np.arange(0,n*dt,dt)
jm = n
paths = []
# Cerco il camminatore che ci ha messo meno ad arrivare ad 1 (sarà questo a decretare la lunghezza degli x_n)
for path in p:
    j = np.argmax(path>=1)
    if jm > j:
        jm = j 

#time = np.arange(-t[jm],0,dt)
# Riformatto tutti gli array per avere la stessa lunghezza
times = []
for path in p:
    j = np.argmax(path>=1)
    if j > jm: # Escludo il più veloce (si potrebbe includere con una riga in più...)
        paths.append(path[:j]) # vado dal primo elemento fino al punto in cui x=1
        times.append(t[:j]-t[j]) # Creo un nuovo array di tempi sincronizzato con questo x_n

# Plotto i risultati in HD
num_plot = 70 # numero di plot da visualizzare
for path in p[:num_plot]:
    j = np.argmax(path>=1)
    plt.plot(t - t[j], path, alpha=0.5, linewidth=0.5)
plt.xlim(-3*t[jm],0)
#plt.savefig("../../figures/lez_12_walker_t_path.png", dpi = 300) 
plt.xlabel('t')
plt.ylabel('x')
plt.show()

# %%
# Concateno tempi e percorsi per visualizzare la densità, avendo sincronizzato tutto non ci saranno problemi.
tot_path = np.concatenate([i for i in paths])
tot_time = np.concatenate([i for i in times])

# Seaborn nella sua incredibile lentezza vuole anche una pandas series anziche un numpy array...
path_series = pd.Series(tot_path)
time_series = pd.Series(tot_time)

print('please wait 60 second...')
plot = sns.kdeplot(x=time_series, y=path_series, cmap="Reds", shade=True)
plot.set(xlim=(-10,0))
plot.set(xlabel='t', ylabel='x')
#plot.figure.savefig("../../figures/lez_12_walker.png", dpi = 300) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-b2cad8e8e982> in <module>
#       1 # Concateno tempi e percorsi per visualizzare la densità, avendo sincronizzato tutto non ci saranno problemi.
# ----> 2 tot_path = np.concatenate([i for i in paths])
#       3 tot_time = np.concatenate([i for i in times])
#       4
#       5 # Seaborn nella sua incredibile lentezza vuole anche una pandas series anziche un numpy array...
#
# NameError: name 'paths' is not defined

# %%
#for x, dw in zip(p,w):
#    plt.plot(x, dw, alpha=0.7)
# Dobbiamo fare la concatenazione anche dei path originali ora, insieme a tutti i rumori  
tot_path1 = np.concatenate([i for i in p[:]])
tot_w = np.concatenate([i for i in w[:]])

# Utilizziamo sempre seaborn, quindi servono delle pd.series:
path1_series = pd.Series(tot_path1)
w_series = pd.Series(tot_w)

# Adesso discretizziamo i percorsi ed valutiamo 
# su ciascuno di questi discretizzati la media del processo di wiener
bins = 30                                                 # numero di bins
step = (max(tot_path1)-min(tot_path1))/bins                # Il passo della discretizzazione
vec_step = np.arange(min(tot_path1), max(tot_path1), step) # percorso discretizzato

# Valuto la media dei w nell'intervallo del bin scelto a piacere
mean_w = np.zeros(bins)
for i in range(1, bins-2):
    mask = (tot_path1>=vec_step[i-1]) & (tot_path1 < vec_step[i]) # maschera per beccare i w appartenenti al bin
    mean_w[i] = np.mean(tot_w[mask]) # valuto la media su questi w

# Plotto i risultati
plot = sns.kdeplot(x=path1_series, y=w_series, cmap="Reds", shade=True)
plot.scatter(vec_step, mean_w, color = 'r')
plot.axhline(0, ls='--', linewidth = 0.5)
plot.set(xlim=(-1.5,1.5))
plot.set(ylim=(-2,2))
plot.set(xlabel='x', ylabel='w')
#plot.figure.savefig("../../figures/lez_12_dist.png", dpi = 300) 
plt.show()

# %%
#%reset

# %%
n, m, dt, eps = get_param()
# Generare un moto instantotico è difficile: deve essere croppato perché non arriva mai ai suoi estremi...
# Per farlo si adottano alcuni stratagemmi / truffe...
k = 330000 # Parametro che decide il passo della simulazione (mooolto sensibile su questo parametro)
s = int(k*dt) # passo della simulazione

#Genero array che parte dalla buca in -1
x = -1*np.ones(s)
# do un colpetto al primo valore sennò il camminatore non parte mai..
x[0] = x[0] + 0.0000001

#Ciclo fino a metà dell'array (non mi interessa che il camminatore arrivi esattamente in zero, ripeto: non ci può arrivare)
for i in range(int(s/2)-1):
    x[i+1] = x[i] - f(x[i])*dt # + dw[i]

# Teletrasporto il camminatore al di là del massimo per farlo continuare
x[int(s/2)] = 0.1
# ciclo sul restante array
for i in range(int(s/2), s-1):
    x[i+1] = x[i] + f(x[i])*dt 

# traslo indietro tutti gli step del secondo ciclo per rendere continua la funzione.
x[int(s/2): s-1] += -0.16

# Scelgo una sottofrazione dell'array da plottare per evitare gli istanti "morti"
a = int(5*len(x)/16)
b = int(11*len(x)/16)
x = x[a:b]
t = np.arange(-5.5,0, 5.5/(len(x)))
plt.plot(t, x)
plt.show()

# %%
# Concateno tempi e percorsi per visualizzare la densità, avendo sincronizzato tutto non ci saranno problemi.
tot_path = np.concatenate([i for i in paths])
tot_time = np.concatenate([i for i in times])

# Seaborn nella sua incredibile lentezza vuole anche una pandas series anziche un numpy array...
path_series = pd.Series(tot_path)
time_series = pd.Series(tot_time)

print('please wait 60 second...')
plot = sns.kdeplot(x=time_series, y=path_series, cmap="Reds", shade=True)
plot.plot(t, x, color='blue')
plot.set(xlim=(-10,0))
plot.set(xlabel='t', ylabel='x')
#plot.figure.savefig("../../figures/lez_12_walker_t_theory.png", dpi = 300) 
plt.show()

# %%
s = 1000
xx0 = np.linspace(-1,0, s)
xx1 = np.linspace(0,1, s)
xx = np.concatenate((xx0,xx1))

ww0 = -2*f(xx0)
ww1 = np.zeros(s)
ww = np.concatenate((ww0,ww1))*(dt/np.sqrt(eps))
plt.plot(xx,ww)
plt.show()

# %%
#for x, dw in zip(p,w):
#    plt.plot(x, dw, alpha=0.7)
# Dobbiamo fare la concatenazione anche dei path originali ora, insieme a tutti i rumori  
tot_path1 = np.concatenate([i for i in p])
tot_w = np.concatenate([i for i in w])

# Utilizziamo sempre seaborn, quindi servono delle pd.series:
path1_series = pd.Series(tot_path1)
w_series = pd.Series(tot_w)

# Adesso discretizziamo i percorsi ed valutiamo 
# su ciascuno di questi discretizzati la media del processo di wiener
bins = 30                                                 # numero di bins
step = (max(tot_path1)-min(tot_path1))/bins                # Il passo della discretizzazione
vec_step = np.arange(min(tot_path1), max(tot_path1), step) # percorso discretizzato

# Valuto la media dei w nell'intervallo del bin scelto a piacere
mean_w = np.zeros(bins)
for i in range(1, bins-2):
    mask = (tot_path1>=vec_step[i-1]) & (tot_path1 < vec_step[i]) # maschera per beccare i w appartenenti al bin
    mean_w[i] = np.mean(tot_w[mask]) # valuto la media su questi w

# Plotto i risultati
plot = sns.kdeplot(x=path1_series, y=w_series, cmap="Reds", shade=True)
plot.scatter(vec_step, mean_w, color = 'r')
plot.plot(xx, ww, color='blue')
plot.axhline(0, ls='--', linewidth = 0.5)
plot.set(xlim=(-1.5,1.5))
plot.set(ylim=(-2,2))
plot.set(xlabel='x', ylabel='w')
#plot.figure.savefig("../../figures/lez_12_dist_theory.png", dpi = 300) 
plt.show()

# %%
def get_param_1():
    n = 2000 # step di ogni camminatore
    m = 10000 # camminatori analizzati
    dt = 0.008
    eps = 0.0005
    return n, m, dt, eps

def main_1():
    np.random.seed(10) # Risultati riproducibili
    mu, sigma = 0, 1 # media e deviazione standard del processo di Wiener
    n, m, dt, eps = get_param_1() # prendo i parametri del problema
    
    # Inizializzo matrice delle posizioni e dei numeri casuali
    print('setting up')
    print('-ones matrix...')
    x = -1*np.ones((n,m)) # Tutti in -1 all'inizio
    print('rand matrix, wait some seconds...')
    dw = np.random.normal(mu, sigma, (n,m))
    
    # muovo i camminatori
    x = motion(x, dw)
    
    # Plotto i risultati e memorizzo i giusti percorsi e le giuste w
    right_paths = []
    right_w = []
    
    tj = n*dt
    t = np.arange(0,n*dt,dt)
    plt.figure(figsize=(20,10))
    for i in range(m):
        j = np.argmax(x[:,i] >= -0.2) # Cerco la prima volta che è stato superato x=-0.2
        k = np.argmax(x[j:,i] >= -0.15)
        if j > 0: # se fa 0 allora vuol dire che non ci è arrivato...
            if k == 0:
                plt.plot(t-t[j], x[:,i], alpha=0.7)
                right_paths.append(x[:,i])
                right_w.append(dw[:,i])
                if tj > t[j]:
                    tj = t[j]
    #plt.xlim(-3*tj,0)
    plt.show()
    return right_paths, right_w
p, w = main_1()
# Out:
# setting up
# -ones matrix...
# rand matrix, wait some seconds...
# start cycling
# 25%
# 50%
# 75%
# done

# %%
print(f'Numero di percorsi ottenuti: {len(p)}')
n, m, dt, eps = get_param()
print(f'rapporto eps/dt = {eps/dt}')
#%reset
# Out:
# Numero di percorsi ottenuti: 28
# rapporto eps/dt = 0.0625

# %%
# Generare un moto instantotico è difficile: deve essere croppato perché non arriva mai ai suoi estremi...
# Per farlo si adottano alcuni stratagemmi / truffe...
k = 300000 # Parametro che decide il passo della simulazione (mooolto sensibile su questo parametro)
s = int(k*dt) # passo della simulazione

#Genero array che parte dalla buca in -1
x = -1*np.ones(s)
# do un colpetto al primo valore sennò il camminatore non parte mai..
x[0] = x[0] + 0.00000004

#Ciclo fino a metà dell'array (non mi interessa che il camminatore arrivi esattamente in zero, ripeto: non ci può arrivare)
for i in range(int(s/2)):
    x[i+1] = x[i] - f(x[i])*dt # + dw[i]

# Teletrasporto il camminatore al di là del massimo per farlo continuare
#x[int(s/2)] = 0.1
# ciclo sul restante array
for i in range(int(s/2), s-1):
    x[i+1] = x[i] + f(x[i])*dt 

# traslo indietro tutti gli step del secondo ciclo per rendere continua la funzione.
#x[int(s/2): s-1] += -0.16

# Scelgo una sottofrazione dell'array da plottare per evitare gli istanti "morti"
a = int(5*len(x)/16)
b = int(11*len(x)/16)
x = x[a:b]
t_0 = np.arange(-5,5, 10/(len(x)))
plt.xlim(-11,11)
plt.plot(t_0, x)
plt.show()

# %%
n, m, dt, eps = get_param_1()

##################################################################
t = np.arange(0,n*dt,dt)
jm = n
paths = []
# Cerco il camminatore che ci ha messo meno ad arrivare ad 1 (sarà questo a decretare la lunghezza degli x_n)
for path in p:
    j = np.argmax(path>=-0.2)
    if jm > j:
        jm = j 

#time = np.arange(-t[jm],0,dt)
# Riformatto tutti gli array per avere la stessa lunghezza
times = []
for path in p:
    j = np.argmax(path>=-0.2)
    if j > jm: # Escludo il più veloce (si potrebbe includere con una riga in più...)
        paths.append(path)
        times.append(t-t[j]) # Creo un nuovo array di tempi sincronizzato con questo x_n

# Plotto i risultati in HD
num_plot = len(p)-1 # numero di plot da visualizzare
for path in p[:num_plot]:
    j = np.argmax(path>=-0.2)
    plt.plot(t - t[j], path, alpha=0.5, linewidth=0.5)
plt.xlim(-11,11)
plt.savefig("../../figures/lez_12_walker_t_cutted.png", dpi = 300) 
plt.xlabel('t')
plt.ylabel('x')
plt.show()

#####################################################################


tot_path = np.concatenate([i for i in paths])
tot_time = np.concatenate([i for i in times])

# Seaborn nella sua incredibile lentezza vuole anche una pandas series anziche un numpy array...
path_series = pd.Series(tot_path)
time_series = pd.Series(tot_time)

print('please wait 60 second...')
plot = sns.kdeplot(x=time_series, y=path_series, cmap="Reds", shade=True)
plot.plot(t_0, x, color='blue')
plot.set(ylim=(-1.2,-0.15))
plot.set(xlim=(-11,11))

plot.set(xlabel='t', ylabel='x')
plot.figure.savefig("../../figures/lez_12_walker_t_cutted_theory.png", dpi = 300) 
plt.show()
# Out:
# please wait 60 second...
